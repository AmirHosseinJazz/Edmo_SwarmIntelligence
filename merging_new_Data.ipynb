# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('NewParameterSamples.csv')

# %%
speed=pd.read_csv('speed_data500_1000.csv')

# %%
speed.columns=['Timestamp','Speed']

# %%
t=pd.merge(speed,data,on=['Timestamp'],how='outer')

# %%
t=t.sort_values(by='Timestamp')

# %%
for i in t.columns:
    if i!='Timestamp' and i!='Speed':
        t[i]=t[i].fillna(method='ffill')

# %%
t=t.dropna(subset=['Snelheid'])

# %%
t['Speed']=t['Speed'].fillna(method='bfill')

# %%
results=t.groupby(['Snelheid', 'Omvang1', 'Positie1', 'Omvang2','Positie2', 'Relatie']).agg({'Speed':np.mean})

# %%
Final=results.reset_index()

# %%
Final
# Out:
#      Snelheid  Omvang1  Positie1  Omvang2  Positie2  Relatie     Speed
# 0         0.0      0.0     -90.0     45.0     -90.0    -60.0  0.720354
# 1         0.0      0.0     -90.0     45.0      30.0     60.0  1.639202
# 2         0.0      0.0     -90.0     60.0      15.0    -45.0  1.243099
# 3         0.0      0.0     -45.0     15.0     -75.0     30.0  1.046268
# 4         0.0      0.0     -45.0     15.0      30.0     30.0  0.325357
# ..        ...      ...       ...      ...       ...      ...       ...
# 493       9.0     75.0     -45.0      0.0     -90.0     30.0  5.130143
# 494       9.0     75.0     -30.0      0.0     -90.0     30.0  4.264560
# 495       9.0     75.0     -30.0     15.0      60.0     30.0  5.720083
# 496       9.0     75.0      30.0     15.0     -15.0    -90.0  5.768844
# 497       9.0     75.0      30.0     45.0     -75.0     75.0  4.581650
#
# [498 rows x 7 columns]

# %%
Final
# Out:
#      Snelheid  Omvang1  Positie1  Omvang2  Positie2  Relatie     Speed
# 0         0.0      0.0     -90.0     45.0     -90.0    -60.0  0.720354
# 1         0.0      0.0     -90.0     45.0      30.0     60.0  1.639202
# 2         0.0      0.0     -90.0     60.0      15.0    -45.0  1.243099
# 3         0.0      0.0     -45.0     15.0     -75.0     30.0  1.046268
# 4         0.0      0.0     -45.0     15.0      30.0     30.0  0.325357
# ..        ...      ...       ...      ...       ...      ...       ...
# 493       9.0     75.0     -45.0      0.0     -90.0     30.0  5.130143
# 494       9.0     75.0     -30.0      0.0     -90.0     30.0  4.264560
# 495       9.0     75.0     -30.0     15.0      60.0     30.0  5.720083
# 496       9.0     75.0      30.0     15.0     -15.0    -90.0  5.768844
# 497       9.0     75.0      30.0     45.0     -75.0     75.0  4.581650
#
# [498 rows x 7 columns]

# %%
Final.to_csv('secondbatch_500Samples.csv')
